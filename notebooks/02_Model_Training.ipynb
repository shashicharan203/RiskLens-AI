# %% [markdown]
# # LedgerMind-AI: Notebook 02 - Model Training & Evaluation
#
# Trains Logistic Regression, Random Forest, XGBoost, and PyTorch Autoencoders with SMOTE class imbalance handling.

# %%
import os
import sys
sys.path.append('..')

from src.models.train import train_and_save_pipeline
train_and_save_pipeline(data_path='data/transactions.csv', output_model_path='models/risk_model.pkl')
